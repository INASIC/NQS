# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from itertools import product

# %% [markdown]
# ## Read in Data
#
# We begin by reading in the trained parameters for several iteration times shown in their file names.
#
# Notes:
# * I have defined seperate files for each of the parameters for each iteration.
#
# This is how they look:

# %%
a_df_iter1 = pd.read_csv('./data/nv=10,nh=20/a_iter=1_eloc=1704.950989.dat', sep='\t', header=None)
a_df_iter1
# Out:
#           0
# 0  0.060532
# 1  0.082953
# 2 -0.066972
# 3  0.002457
# 4  0.010363
# 5  0.042907
# 6 -0.076674
# 7 -0.002381
# 8 -0.015472
# 9  0.005805

# %%
b_df_iter1 = pd.read_csv('./data/nv=10,nh=20/b_iter=1_eloc=1704.950989.dat', sep='\t', header=None)
b_df_iter1
# Out:
#            0
# 0  -0.007044
# 1  -0.012387
# 2  -0.013960
# 3   0.001946
# 4   0.010194
# 5  -0.011641
# 6   0.024754
# 7  -0.001518
# 8   0.001227
# 9   0.016409
# 10  0.017506
# 11  0.005964
# 12 -0.006020
# 13 -0.021239
# 14 -0.016477
# 15 -0.004861
# 16  0.000133
# 17 -0.008392
# 18 -0.009904
# 19 -0.006414

# %%
W_df_iter1 = pd.read_csv('./data/nv=10,nh=20/W_iter=1_eloc=1704.950989.dat', sep='\s+', header=None)
W_df_iter1
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.030191  0.028976  0.020457  0.036200  0.043135  0.005999  0.044686
# 1  0.042433  0.028898  0.053225  0.029962  0.052802  0.044271  0.052286
# 2 -0.029219 -0.010609 -0.025523 -0.045261 -0.036538 -0.018935 -0.041330
# 3 -0.003998 -0.015942 -0.012318 -0.004773 -0.009234 -0.011237 -0.001104
# 4 -0.003542  0.004739 -0.008211  0.008609  0.013841  0.014858 -0.009799
# 5  0.023288  0.008618  0.022383  0.009730  0.018126  0.011249  0.033426
# 6 -0.038947 -0.049074 -0.010768 -0.031610 -0.028731 -0.045232 -0.029177
# 7 -0.017115 -0.000469  0.012161  0.004559 -0.013380  0.014214 -0.000619
# 8 -0.003823 -0.006234 -0.010323 -0.019766 -0.012829 -0.017365 -0.003538
# 9 -0.001466  0.010913  0.007800 -0.002573  0.003121 -0.008276 -0.012502
#
#          7         8         9         10        11        12        13  \
# 0  0.016088  0.024170  0.029631  0.013584  0.007810  0.038162  0.041380
# ...

# %%
# Read the rest of the data
a_df_iter1 = pd.read_csv('./data/nv=10,nh=20/a_iter=1_eloc=1704.950989.dat', sep='\t', header=None)
b_df_iter1 = pd.read_csv('./data/nv=10,nh=20/b_iter=1_eloc=1704.950989.dat', sep='\t', header=None)
W_df_iter1 = pd.read_csv('./data/nv=10,nh=20/W_iter=1_eloc=1704.950989.dat', sep='\s+', header=None)

a_df_iter10 = pd.read_csv('./data/nv=10,nh=20/a_iter=10_eloc=804.190090.dat', sep='\t', header=None)
b_df_iter10 = pd.read_csv('./data/nv=10,nh=20/b_iter=10_eloc=804.190090.dat', sep='\t', header=None)
W_df_iter10 = pd.read_csv('./data/nv=10,nh=20/W_iter=10_eloc=804.190090.dat', sep='\s+', header=None)

a_df_iter100 = pd.read_csv('./data/nv=10,nh=20/a_iter=100_eloc=99.855636.dat', sep='\t', header=None)
b_df_iter100 = pd.read_csv('./data/nv=10,nh=20/b_iter=100_eloc=99.855636.dat', sep='\t', header=None)
W_df_iter100 = pd.read_csv('./data/nv=10,nh=20/W_iter=100_eloc=99.855636.dat', sep='\s+', header=None)

a_df_iter1000 = pd.read_csv('./data/nv=10,nh=20/a_iter=1000_eloc=4.535628.dat', sep='\t', header=None)
b_df_iter1000 = pd.read_csv('./data/nv=10,nh=20/b_iter=1000_eloc=4.535628.dat', sep='\t', header=None)
W_df_iter1000 = pd.read_csv('./data/nv=10,nh=20/W_iter=1000_eloc=4.535628.dat', sep='\s+', header=None)

a_df_iter10000 = pd.read_csv('./data/nv=10,nh=20/a_iter=10000_eloc=0.878325.dat', sep='\t', header=None)
b_df_iter10000 = pd.read_csv('./data/nv=10,nh=20/b_iter=10000_eloc=0.878325.dat', sep='\t', header=None)
W_df_iter10000 = pd.read_csv('./data/nv=10,nh=20/W_iter=10000_eloc=0.878325.dat', sep='\s+', header=None)

a_df_iter15000 = pd.read_csv('./data/nv=10,nh=20/a_iter=15000_eloc=2.036470.dat', sep='\t', header=None)
b_df_iter15000 = pd.read_csv('./data/nv=10,nh=20/b_iter=15000_eloc=2.036470.dat', sep='\t', header=None)
W_df_iter15000 = pd.read_csv('./data/nv=10,nh=20/W_iter=15000_eloc=2.036470.dat', sep='\s+', header=None)

a_df_iter20000 = pd.read_csv('./data/nv=10,nh=20/a_iter=20000_eloc=0.016512.dat', sep='\t', header=None)
b_df_iter20000 = pd.read_csv('./data/nv=10,nh=20/b_iter=20000_eloc=0.016512.dat', sep='\t', header=None)
W_df_iter20000 = pd.read_csv('./data/nv=10,nh=20/W_iter=20000_eloc=0.016512.dat', sep='\s+', header=None)

# %%
# Put the dataframes into lists of lists
list_params_iter1 = [a_df_iter1, b_df_iter1, W_df_iter1]
list_params_iter10 = [a_df_iter10, b_df_iter10, W_df_iter10]
list_params_iter100 = [a_df_iter100, b_df_iter100, W_df_iter100]
list_params_iter1000 = [a_df_iter1000, b_df_iter1000, W_df_iter1000]
list_params_iter10000 = [a_df_iter10000, b_df_iter10000, W_df_iter10000]
list_params_iter15000 = [a_df_iter15000, b_df_iter15000, W_df_iter15000]
list_params_iter20000 = [a_df_iter20000, b_df_iter20000, W_df_iter20000]

list_list_params = [list_params_iter1, list_params_iter10, list_params_iter100, list_params_iter1000, list_params_iter10000, list_params_iter15000, list_params_iter20000]

# %% [markdown]
# # Compare all Wavefunctions

# %% [markdown]
# Here we use the parameters that were read in to evaluate the PDF of the RBM (at each value of x) - and then square root it to plot $\psi$.

# %%
list_data_names = ['iter=1 | eloc=1704.950989', 'iter=10 | eloc=804.190090', 'iter=100 | eloc=99.855636', 'iter=1000 | eloc=4.535628.', 'iter=10,000 | eloc=0.878325', 'iter=15,000 | eloc=2.036470', 'iter=20,000 | eloc=0.016512'] 
counter = 0

# Loop over each dataset
# for list_list in list_list_params:
list_list = list_params_iter1000

a = np.array(list_list[0])
b = np.array(list_list[1])
W = np.array(list_list[2])

a = np.flip(a,0)  # We defined our bytes in reverse order, flip them so it is consistent
W = np.flip(W,0)

# Create bytes representing meshpoint location, i
sigma = np.zeros((1024,10)) 
ind = 0
for i in product([0,1], repeat=10):
    sigma[ind,:] = i
    ind+=1
sigma = np.flip(sigma,1)  # Flip them for consistency

x = np.arange(-10+120/1024, 110+120/1024, 120/1024)

# Evaluate PDF, prob, using parameters of the RBM
prob = np.zeros(1024)
for n in range(1024):
    firstsum = np.dot(sigma[n,:],a)
    productsum = 1
    for j in range(len(b)):
        productsum *= 2*np.cosh(np.dot(W[:,j],sigma[n,:])+ b[j])
    prob[n]= np.exp(firstsum) * productsum        

# Convert PDF into wavefn., plot it
fig=plt.figure(figsize=(5, 5))
plt.rcParams.update({'font.size': 17})
plt.plot(x, np.sqrt(prob))
#     plt.title(list_data_names[counter])
counter += 1
plt.ylabel('$\Psi$')
plt.xlabel('x')
plt.axvline(x=0, c='k', label='potential barrier')
plt.axvline(x=100, c='k')
plt.legend(loc=4)
#     plt.ylim(0,10000)
plt.savefig('recon_psi', dpi = 300, bbox_inches='tight')
plt.show()
