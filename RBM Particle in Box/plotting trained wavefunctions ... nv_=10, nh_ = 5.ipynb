# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from itertools import product

# %% [markdown]
# ## Read in Data
#
# We begin by reading in the trained parameters for several iteration times shown in their file names.
#
# Notes:
# * I have defined seperate files for each of the parameters for each iteration.
#
# This is how they look:

# %%
a_df_iter1 = pd.read_csv('./data/nv=10,nh=5/a_iter=1_eloc=1799.744289.dat', sep='\t', header=None)
a_df_iter1
# Out:
#           0
# 0  0.015529
# 1  0.096909
# 2  0.020011
# 3 -0.037698
# 4  0.070766
# 5  0.016981
# 6  0.044781
# 7  0.064041
# 8  0.109565
# 9  0.123467

# %%
b_df_iter1 = pd.read_csv('./data/nv=10,nh=5/b_iter=1_eloc=1799.744289.dat', sep='\t', header=None)
b_df_iter1
# Out:
#           0
# 0 -0.005024
# 1 -0.009420
# 2 -0.012024
# 3  0.003545
# 4  0.011779

# %%
W_df_iter1 = pd.read_csv('./data/nv=10,nh=5/W_iter=1_eloc=1799.744289.dat', sep='\s+', header=None)
W_df_iter1
# Out:
#           0         1         2         3         4
# 0 -0.001280  0.034381  0.008278  0.010975  0.026432
# 1  0.070140  0.059916  0.046611  0.031804  0.037626
# 2  0.010282  0.015890  0.006073  0.005136  0.008557
# 3 -0.020472 -0.021142 -0.030957 -0.015245 -0.009024
# 4  0.015631  0.053106  0.024876  0.032634  0.038364
# 5 -0.009821 -0.015513  0.015003  0.017800 -0.004038
# 6  0.022810  0.023713  0.039479  0.035075  0.036538
# 7  0.033356  0.020129  0.044240  0.019856  0.042811
# 8  0.054012  0.062183  0.041738  0.064264  0.064249
# 9  0.061239  0.061169  0.047614  0.060301  0.054352

# %%
# Read the rest of the data
a_df_iter1 = pd.read_csv('./data/nv=10,nh=5/a_iter=1_eloc=1799.744289.dat', sep='\t', header=None)
b_df_iter1 = pd.read_csv('./data/nv=10,nh=5/b_iter=1_eloc=1799.744289.dat', sep='\t', header=None)
W_df_iter1 = pd.read_csv('./data/nv=10,nh=5/W_iter=1_eloc=1799.744289.dat', sep='\s+', header=None)

a_df_iter10 = pd.read_csv('./data/nv=10,nh=5/a_iter=10_eloc=1504.930995.dat', sep='\t', header=None)
b_df_iter10 = pd.read_csv('./data/nv=10,nh=5/b_iter=10_eloc=1504.930995.dat', sep='\t', header=None)
W_df_iter10 = pd.read_csv('./data/nv=10,nh=5/W_iter=10_eloc=1504.930995.dat', sep='\s+', header=None)

a_df_iter100 = pd.read_csv('./data/nv=10,nh=5/a_iter=100_eloc=122.124122.dat', sep='\t', header=None)
b_df_iter100 = pd.read_csv('./data/nv=10,nh=5/b_iter=100_eloc=122.124122.dat', sep='\t', header=None)
W_df_iter100 = pd.read_csv('./data/nv=10,nh=5/W_iter=100_eloc=122.124122.dat', sep='\s+', header=None)

a_df_iter1000 = pd.read_csv('./data/nv=10,nh=5/a_iter=1000_eloc=0.479037.dat', sep='\t', header=None)
b_df_iter1000 = pd.read_csv('./data/nv=10,nh=5/b_iter=1000_eloc=0.479037.dat', sep='\t', header=None)
W_df_iter1000 = pd.read_csv('./data/nv=10,nh=5/W_iter=1000_eloc=0.479037.dat', sep='\s+', header=None)

a_df_iter10000 = pd.read_csv('./data/nv=10,nh=5/a_iter=10000_eloc=2.835982.dat', sep='\t', header=None)
b_df_iter10000 = pd.read_csv('./data/nv=10,nh=5/b_iter=10000_eloc=2.835982.dat', sep='\t', header=None)
W_df_iter10000 = pd.read_csv('./data/nv=10,nh=5/W_iter=10000_eloc=2.835982.dat', sep='\s+', header=None)

a_df_iter15000 = pd.read_csv('./data/nv=10,nh=5/a_iter=15000_eloc=-0.005182.dat', sep='\t', header=None)
b_df_iter15000 = pd.read_csv('./data/nv=10,nh=5/b_iter=15000_eloc=-0.005182.dat', sep='\t', header=None)
W_df_iter15000 = pd.read_csv('./data/nv=10,nh=5/W_iter=15000_eloc=-0.005182.dat', sep='\s+', header=None)

a_df_iter20000 = pd.read_csv('./data/nv=10,nh=5/a_iter=20000_eloc=0.712372.dat', sep='\t', header=None)
b_df_iter20000 = pd.read_csv('./data/nv=10,nh=5/b_iter=20000_eloc=0.712372.dat', sep='\t', header=None)
W_df_iter20000 = pd.read_csv('./data/nv=10,nh=5/W_iter=20000_eloc=0.712372.dat', sep='\s+', header=None)

# %%
# Put the dataframes into lists of lists
list_params_iter1 = [a_df_iter1, b_df_iter1, W_df_iter1]
list_params_iter10 = [a_df_iter10, b_df_iter10, W_df_iter10]
list_params_iter100 = [a_df_iter100, b_df_iter100, W_df_iter100]
list_params_iter1000 = [a_df_iter1000, b_df_iter1000, W_df_iter1000]
list_params_iter10000 = [a_df_iter10000, b_df_iter10000, W_df_iter10000]
list_params_iter15000 = [a_df_iter15000, b_df_iter15000, W_df_iter15000]
list_params_iter20000 = [a_df_iter20000, b_df_iter20000, W_df_iter20000]

list_list_params = [list_params_iter1, list_params_iter10, list_params_iter100, list_params_iter1000, list_params_iter10000, list_params_iter15000, list_params_iter20000]

# %% [markdown]
# # Compare all Wavefunctions

# %% [markdown]
# Here we use the parameters that were read in to evaluate the PDF of the RBM (at each value of x) - and then square root it to plot $\psi$.
#
# * Note that the energies in the titles of the plot for these are incorrect. I am only interested in the shape of $

# %%
list_data_names = ['iter=1 | eloc=1704.950989', 'iter=10 | eloc=804.190090', 'iter=100 | eloc=99.855636', 'ter=1000| eloc=4.535628', 'iter=10,000 | eloc=0.878325', 'iter=15,000 | eloc=2.036470', 'iter=20,000 | eloc=0.016512'] 
counter = 0

# Loop over each dataset
for list_list in list_list_params:
    a = np.array(list_list[0])
    b = np.array(list_list[1])
    W = np.array(list_list[2])

    a = np.flip(a,0)  # We defined our bytes in reverse order, flip them so it is consistent
    W = np.flip(W,0)

    # Create bytes representing meshpoint location, i
    sigma = np.zeros((1024,10)) 
    ind = 0
    for i in product([0,1], repeat=10):
        sigma[ind,:] = i
        ind+=1
    sigma = np.flip(sigma,1)  # Flip them for consistency

    x = np.arange(-10+120/1024, 110+120/1024, 120/1024)

    # Evaluate PDF, prob, using parameters of the RBM
    prob = np.zeros(1024)
    for n in range(1024):
        firstsum = np.dot(sigma[n,:],a)
        productsum = 1
        for j in range(len(b)):
            productsum *= 2*np.cosh(np.dot(W[:,j],sigma[n,:])+ b[j])
        prob[n]= np.exp(firstsum) * productsum        

    # Convert PDF into wavefn., plot it
    plt.plot(x, np.sqrt(prob))
    plt.title(list_data_names[counter])
    counter += 1
    plt.ylabel('$\Psi$')
    plt.xlabel('x')
    plt.axvline(x=0, c='k', label='potential barrier')
    plt.axvline(x=100, c='k')
    plt.legend(loc=4)
#     plt.ylim(0,10000)
    plt.show()

# %% [markdown]
# * We observe that in the later wavefunctions, they go to extremely large values (1e7 - 1e12). Set these as the limits of our graphs to more easily compare.

# %%
list_data_names = ['iter=1 | eloc=1704.950989', 'iter=10 | eloc=804.190090', 'iter=100 | eloc=99.855636', 'ter=1000| eloc=4.535628', 'iter=10,000 | eloc=0.878325', 'iter=15,000 | eloc=2.036470', 'iter=20,000 | eloc=0.016512'] 
counter = 0

# Loop over each dataset
for list_list in list_list_params:
    a = np.array(list_list[0])
    b = np.array(list_list[1])
    W = np.array(list_list[2])

    a = np.flip(a,0)  # We defined our bytes in reverse order, flip them so it is consistent
    W = np.flip(W,0)

    # Create bytes representing meshpoint location, i
    sigma = np.zeros((1024,10)) 
    ind = 0
    for i in product([0,1], repeat=10):
        sigma[ind,:] = i
        ind+=1
    sigma = np.flip(sigma,1)  # Flip them for consistency

    x = np.arange(-10+120/1024, 110+120/1024, 120/1024)

    # Evaluate PDF, prob, using parameters of the RBM
    prob = np.zeros(1024)
    for n in range(1024):
        firstsum = np.dot(sigma[n,:],a)
        productsum = 1
        for j in range(len(b)):
            productsum *= 2*np.cosh(np.dot(W[:,j],sigma[n,:])+ b[j])
        prob[n]= np.exp(firstsum) * productsum        

    # Convert PDF into wavefn., plot it
    plt.plot(x, np.sqrt(prob))
    plt.title(list_data_names[counter])
    counter += 1
    plt.ylabel('$\Psi$')
    plt.xlabel('x')
    plt.axvline(x=0, c='k', label='potential barrier')
    plt.axvline(x=100, c='k')
    plt.legend(loc=4)
    plt.ylim(0,1e7)  # See here
    plt.show()

# %% [markdown]
# * Observe the graphs for smaller y limits: (0-100)

# %%
list_data_names = ['iter=1 | eloc=1704.950989', 'iter=10 | eloc=804.190090', 'iter=100 | eloc=99.855636', 'ter=1000| eloc=4.535628', 'iter=10,000 | eloc=0.878325', 'iter=15,000 | eloc=2.036470', 'iter=20,000 | eloc=0.016512'] 
counter = 0

# Loop over each dataset
for list_list in list_list_params:
    a = np.array(list_list[0])
    b = np.array(list_list[1])
    W = np.array(list_list[2])

#     a = np.flip(a,0)  # We defined our bytes in reverse order, flip them so it is consistent
#     W = np.flip(W,0)

    # Create bytes representing meshpoint location, i
    sigma = np.zeros((1024,10)) 
    ind = 0
    for i in product([0,1], repeat=10):
        sigma[ind,:] = i
        ind+=1
#     sigma = np.flip(sigma,1)  # Flip them for consistency

    x = np.arange(-10+120/1024, 110+120/1024, 120/1024)

    # Evaluate PDF, prob, using parameters of the RBM
    prob = np.zeros(1024)
    for n in range(1024):
        firstsum = np.dot(sigma[n,:],a)
        productsum = 1
        for j in range(len(b)):
            productsum *= 2*np.cosh(np.dot(W[:,j],sigma[n,:])+ b[j])
        prob[n]= np.exp(firstsum) * productsum        

    # Convert PDF into wavefn., plot it
    plt.plot(x, np.sqrt(prob))
    plt.title(list_data_names[counter])
    counter += 1
    plt.ylabel('$\Psi$')
    plt.xlabel('x')
    plt.axvline(x=0, c='k', label='potential barrier')
    plt.axvline(x=100, c='k')
    plt.legend(loc=4)
    plt.ylim(0,100)  # See here
    plt.show()

# %% [markdown]
# * Note that there is no difference whether we reverse the bytes, and associated parameters

# %%
list_data_names = ['iter=1 | eloc=1704.950989', 'iter=10 | eloc=804.190090', 'iter=100 | eloc=99.855636', 'ter=1000| eloc=4.535628', 'iter=10,000 | eloc=0.878325', 'iter=15,000 | eloc=2.036470', 'iter=20,000 | eloc=0.016512'] 
counter = 0

# Loop over each dataset
for list_list in list_list_params:
    a = np.array(list_list[0])
    b = np.array(list_list[1])
    W = np.array(list_list[2])

#     a = np.flip(a,0)  # We defined our bytes in reverse order, flip them so it is consistent
#     W = np.flip(W,0)

    # Create bytes representing meshpoint location, i
    sigma = np.zeros((1024,10)) 
    ind = 0
    for i in product([0,1], repeat=10):
        sigma[ind,:] = i
        ind+=1
#     sigma = np.flip(sigma,1)  # Flip them for consistency

    x = np.arange(-10+120/1024, 110+120/1024, 120/1024)

    # Evaluate PDF, prob, using parameters of the RBM
    prob = np.zeros(1024)
    for n in range(1024):
        firstsum = np.dot(sigma[n,:],a)
        productsum = 1
        for j in range(len(b)):
            productsum *= 2*np.cosh(np.dot(W[:,j],sigma[n,:])+ b[j])
        prob[n]= np.exp(firstsum) * productsum        

    # Convert PDF into wavefn., plot it
    plt.plot(x, np.sqrt(prob))
    plt.title(list_data_names[counter])
    counter += 1
    plt.ylabel('$\Psi$')
    plt.xlabel('x')
    plt.axvline(x=0, c='k', label='potential barrier')
    plt.axvline(x=100, c='k')
    plt.legend(loc=4)
    plt.show()
